# %%
import pandas as pd
from datetime import datetime

# %%
def Nao(x):
    if x == None:
        return 'Nao'
    else:
        return x

# %% [raw]
# hist = pd.read_excel('Excel/Histórico.xlsx')
# cons = pd.read_excel('Excel/Consultas.xlsx')
# cons.set_index('Nome',inplace=True)
# hist.set_index('Nome',inplace=True)
# nome='Jorge'
# row = cons.iloc[0]
# row = dict(row,sort = True)
# cons = cons.drop(nome)
# row = pd.DataFrame(row,index =  [0])
# row['Nome'] = nome
# row['Enviado']= 'Nao'
# row

# %%
hist = pd.read_excel('Excel/Histórico.xlsx')
cons = pd.read_excel('Excel/Consultas.xlsx')
cons.set_index('Nome',inplace=True)
cons
# Out:
#                                   E-mail  Dia  Mes   Ano   Horario   Medico
# Nome
# Jorge          koiseroverbr694@gmail.com    1    8  2019  10:00:00  Luciano
# Armando     lucas.barbosa.0899@poli.ufrj    5    8  2019  11:00:00    Katia
# Aristhenes  lucas.barbosa.0899@gmail.com    6    8  2019  11:30:00   Marcio
# Leila          koiseroverbr694@gmail.com    7    8  2019  12:00:00  Claudio

# %%
hist
# Out:
#                                      E-mail  Dia  Mes   Ano   Horario  \
# Nome
# Jose           lucas.barbosa.0899@gmail.com   31    8  2019  08:30:00
# Luccas      lucas.barbosa.0899@poli.ufrj.br   31    8  2019  09:00:00
# Ana            lucas.barbosa.0899@gmail.com   25    8  2019  09:30:00
# Luiza          lucas.barbosa.0899@gmail.com   26    8  2019  10:00:00
# Jorge             koiseroverbr694@gmail.com   27    8  2019  10:30:00
# Clara          lucas.barbosa.0899@gmail.com   28    8  2019  11:00:00
# Armando        lucas.barbosa.0899@poli.ufrj   29    8  2019  11:30:00
# Aristhenes     lucas.barbosa.0899@gmail.com   30    8  2019  12:00:00
# Leila             koiseroverbr694@gmail.com   31    8  2019  12:30:00
# Ana         lucas.barbosa.0899@poli.ufrj.br   31    7  2019  09:00:00
# Luiza          lucas.barbosa.0899@gmail.com    1    8  2019  09:30:00
#
#              Medico Enviado
# Nome
# Jose          Katia     Sim
# Luccas       Marcio     Sim
# Ana         Claudio     Nao
# Luiza       Luciano     Nao
# Jorge         Jorge     Nao
# Clara         Katia     Nao
# Armando      Marcio     Nao
# Aristhenes  Claudio     Nao
# Leila       Luciano     Nao
# Ana          Marcio     Nao
# Luiza       Claudio     Nao
